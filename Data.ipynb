# %%
# %load_ext autoreload
# %autoreload 2
% matplotlib inline

# %%
import pandas as pd
import seaborn as sns
pd.set_option('max_columns', 80)
pd.set_option('max_colwidth',400)

# %%
from lac.plot import plot_with_roads
from lac.get import crimes, repairs, roads, streetlights, workorders, service_requests

# %% [markdown]
# ## Crimes

# %%
crimes = crimes.compute()
crimes.info()
crimes.head()
# Out:
# [########################################] | 100% Completed |  3.4s
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 285689 entries, 0 to 31582
# Data columns (total 23 columns):
# CCN                     285689 non-null object
# REPORT_DAT              285689 non-null datetime64[ns]
# SHIFT                   285689 non-null category
# METHOD                  285689 non-null object
# OFFENSE                 285689 non-null category
# BLOCK                   285689 non-null object
# XBLOCK                  285689 non-null float64
# YBLOCK                  285689 non-null float64
# WARD                    285677 non-null object
# ANC                     285689 non-null object
# DISTRICT                285522 non-null object
# PSA                     285504 non-null object
# NEIGHBORHOOD_CLUSTER    282041 non-null object
# BLOCK_GROUP             284828 non-null object
# CENSUS_TRACT            284828 non-null object
# VOTING_PRECINCT         285622 non-null object
# LATITUDE                285689 non-null float64
# LONGITUDE               285689 non-null float64
# BID                     46341 non-null object
# START_DATE              285681 non-null datetime64[ns]
# END_DATE                275926 non-null datetime64[ns]
# OBJECTID                285689 non-null int64
# geometry                285689 non-null object
# dtypes: category(2), datetime64[ns](3), float64(4), int64(1), object(13)
# memory usage: 48.5+ MB
#         CCN          REPORT_DAT     SHIFT  METHOD                     OFFENSE  \
# 0  17046092 2018-01-29 00:00:00  MIDNIGHT  OTHERS                    HOMICIDE
# 1  18000025 2018-01-01 01:26:04  MIDNIGHT  OTHERS                 THEFT/OTHER
# 2  18000063 2018-01-01 02:59:43  MIDNIGHT  OTHERS                    BURGLARY
# 3  18000080 2018-01-01 02:45:00  MIDNIGHT  OTHERS                     ROBBERY
# 4  18000158 2018-01-01 04:47:20  MIDNIGHT  OTHERS  ASSAULT W/DANGEROUS WEAPON
#
#                                  BLOCK    XBLOCK    YBLOCK WARD ANC DISTRICT  \
# 0     5400 - 5599 BLOCK OF C STREET SE  406737.0  135154.0    7  7E        6
# 1  1500 - 1599 BLOCK OF 22ND STREET NW  395767.0  138059.0    2  2D        2
# 2  3400 3499  BLOCK OF WHEELER ROAD SE  400554.0  130271.0    8  8C        7
# 3  1900 - 1920 BLOCK OF 14TH STREET NW  397228.0  138674.0    2  2B        3
# 4       600 - 699 BLOCK OF H STREET NW  398185.0  136884.0    2  2C        1
#
#    PSA NEIGHBORHOOD_CLUSTER BLOCK_GROUP CENSUS_TRACT VOTING_PRECINCT  \
# 0  604           Cluster 33    009905 2       009905    Precinct 105
# 1  208            Cluster 6    004100 3       004100     Precinct 14
# 2  705           Cluster 39    009804 1       009804    Precinct 122
# 3  301            Cluster 3    004300 2       004300    Precinct 141
# 4  102            Cluster 8    005800 2       005800    Precinct 129
#
#     LATITUDE  LONGITUDE       BID          START_DATE            END_DATE  \
# 0  38.884198 -76.922352      None 2017-03-21 15:00:37 2017-03-21 21:36:09
# 1  38.910383 -77.048806      None 2017-12-31 20:00:08 2017-12-31 23:55:47
# 2  38.840235 -76.993619      None 2017-12-31 21:20:35 2017-12-31 23:36:11
# 3  38.915929 -77.031963      None 2018-01-01 01:49:14 2018-01-01 02:45:00
# 4  38.899806 -77.020924  DOWNTOWN 2018-01-01 02:26:26 2018-01-01 02:27:31
#
#     OBJECTID                                     geometry
# 0  122552223  POINT (406736.8033200115 135154.8642473567)
# 1  122567393  POINT (395766.8010350095 138059.8645884403)
# 2  122567394  POINT (400553.8021793573 130271.8631148086)
# 3  122567395  POINT (397227.8013164966 138674.8647463207)
# 4  122567397  POINT (398184.8015505272 136884.8644045677)

# %%
plot_with_roads(crimes, markersize=2, alpha=0.1).compute()
# Out:
# [########################################] | 100% Completed | 28.0s

# %% [markdown]
# ## Repairs

# %%
repairs = repairs.compute()
# Out:
# [########################################] | 100% Completed |  6.7s

# %%
repairs.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 5930 entries, 13372 to 302394
# Data columns (total 59 columns):
# OBJECTID                  5930 non-null int64
# WORKORDERID               5930 non-null object
# PROJECTID                 10 non-null float64
# DESCRIPTION               5930 non-null object
# STATUS                    5930 non-null object
# INITIATEDDATE             5930 non-null datetime64[ns]
# WORKORDERCLOSEDDATE       5930 non-null datetime64[ns]
# ACTUALSTARTDATE           4699 non-null object
# ACTUALFINISHDATE          5930 non-null object
# PROJECTNAME               3 non-null object
# PRIORITY                  5842 non-null object
# SOURCEWORKORDERID         30 non-null object
# CYCLETYPE                 5930 non-null object
# SCHEDULEDATE              0 non-null object
# WORKORDERCATEGORY         8 non-null object
# UNATTACHED                5930 non-null object
# WORKORDERCOST             5930 non-null float64
# WORKORDERLABORCOST        5930 non-null float64
# WORKORDERMATERIALCOST     5930 non-null float64
# WORKORDEREQUIPMENTCOST    5930 non-null float64
# SUBMITTEDTO               24 non-null object
# SUBMITTEDTODATE           23 non-null object
# WORKCOMPLETEDBY           1 non-null object
# WORKORDERCLOSEDBY         5930 non-null object
# ISCANCELED                5930 non-null object
# CANCELEDBY                0 non-null object
# CANCELEDDATE              0 non-null object
# ASSETGROUP                5930 non-null object
# SUPERVISOR                6 non-null object
# REQUESTEDBY               35 non-null object
# INITIATEDBY               5930 non-null object
# ADDRESS                   5821 non-null object
# FISCALYEAR                5930 non-null int64
# WARD                      5920 non-null object
# QUADRANT                  5818 non-null object
# ZIPCODE                   5839 non-null object
# ANC                       5818 non-null object
# SMD                       5818 non-null object
# NEIGHBORHOODCLUSTERS      5626 non-null object
# NEIGHBORHOODNAMES         9 non-null object
# BID                       877 non-null object
# AWI                       370 non-null object
# EDZ                       264 non-null object
# NIF                       1417 non-null object
# HISTORICDISTRICT          1081 non-null object
# ZONING                    5820 non-null object
# PUD                       94 non-null object
# CFAR                      0 non-null object
# PSA                       5865 non-null object
# PD                        5865 non-null object
# DAYSTOCLOSE               5930 non-null int64
# UPDATEDATE                5930 non-null object
# XCOORD                    5930 non-null float64
# YCOORD                    5930 non-null float64
# ONSEGX                    5930 non-null float64
# ONSEGY                    5930 non-null float64
# LONGITUDE                 5930 non-null float64
# LATITUDE                  5930 non-null float64
# geometry                  5930 non-null object
# dtypes: datetime64[ns](2), float64(11), int64(3), object(43)
# memory usage: 2.7+ MB

# %%
repairs['WORKORDERCLOSEDDATE'] - repairs['INITIATEDDATE']
# Out:
# 13372    1119 days 05:42:59
# 13429       0 days 00:34:49
# 30926       0 days 00:00:27
# 46981       0 days 21:44:13
# 66662     894 days 21:25:22
# 80203    1120 days 03:40:54
# 80622    1120 days 04:36:40
# 96856    1120 days 03:53:38
# 97350    1120 days 03:23:07
# 112911      0 days 00:30:25
# 129724      0 days 22:15:57
# 129751      0 days 18:08:30
# 130771      0 days 00:21:34
# 130824   1120 days 04:44:04
# 186255    377 days 00:18:55
# 186256    377 days 00:06:38
# 186257    377 days 00:06:37
# 186258    377 days 00:06:36
# 186259    377 days 00:06:30
# 186260    377 days 00:06:17
# 186262    377 days 00:05:23
# 186266    376 days 23:48:29
# 194386    315 days 04:07:53
# 202500    194 days 18:32:58
# 202688    236 days 00:30:53
# 206346     68 days 15:58:44
# 207664      0 days 01:14:44
# 207670      0 days 01:00:36
# 207675    193 days 05:17:19
# 207676    193 days 03:44:46
#                 ...
# 281228      1 days 07:18:50
# 282509      1 days 20:08:51
# 282699     17 days 21:06:01
# 284405      7 days 11:47:46
# 284748      7 days 13:08:44
# 285381      1 days 15:27:52
# 285792      1 days 13:13:25
# 285910      0 days 19:25:41
# 286291      1 days 13:16:45
# 286416      0 days 17:58:19
# 286855      1 days 13:15:32
# 286882      1 days 07:03:46
# 286895      1 days 16:27:13
# 287000      0 days 18:33:35
# 287431     12 days 16:15:38
# 287445     21 days 17:26:03
# 291577     23 days 00:35:51
# 293173     20 days 04:37:08
# 293177     20 days 04:26:32
# 293179     20 days 04:21:45
# 293182     20 days 04:16:49
# 293399     19 days 06:18:50
# 293400     19 days 06:16:01
# 293402     19 days 06:08:07
# 293976      0 days 08:45:15
# 294433      0 days 22:21:03
# 296477      1 days 20:10:52
# 297955      0 days 14:09:50
# 300813    107 days 19:24:00
# 302394      1 days 20:33:18
# dtype: timedelta64[ns]

# %%
repairs[['INITIATEDDATE', 'WORKORDERCLOSEDDATE']].describe([0, 0.25, 0.5, 0.75, 1], 'all')
# Out:
#               INITIATEDDATE  WORKORDERCLOSEDDATE
# count                  5930                 5930
# unique                 5919                 5860
# top     2016-12-14 03:31:21  2017-04-24 18:03:19
# freq                      3                    8
# first   2014-02-24 10:15:04  2014-02-25 08:37:02
# last    2018-02-06 12:43:43  2018-02-08 11:08:05

# %% [markdown]
# ## Streetlights

# %%
streetlights_df = streetlights.compute()
# Out:
# [########################################] | 100% Completed | 39.5s

# %%
streetlights_df.info()
streetlights_df.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 70213 entries, 0 to 70212
# Data columns (total 96 columns):
# OBJECTID                   70213 non-null int64
# FACILITYID                 70212 non-null object
# PEPCOLIGHTID               29375 non-null object
# ASSETTYPE                  70213 non-null int64
# ISMETERED                  70207 non-null float64
# LIGHTTYPE                  70170 non-null float64
# POLETYPE                   70004 non-null object
# POLEHEIGHT                 69806 non-null object
# POWERFEED                  70195 non-null float64
# NUMBERARMS                 66309 non-null float64
# PROXIMITY                  70061 non-null float64
# STREETNAME                 70213 non-null object
# QUADRANT                   70213 non-null int64
# CROSSSTREET                70142 non-null object
# ROADTYPE                   70213 non-null int64
# OWNER                      70213 non-null int64
# WARD                       70213 non-null int64
# COMMENTS                   2584 non-null object
# HOUSENO                    69376 non-null object
# RMS                        70191 non-null float64
# STREETSEGMID               70213 non-null int64
# OTHEREQUIPMENT             5091 non-null object
# CONDITION                  3946 non-null float64
# CREATED_USER               3431 non-null object
# CREATED_DATE               3431 non-null object
# LASTMODIFIED               10892 non-null object
# LIGHTHISTORY               69096 non-null object
# INOPERATION                3940 non-null object
# ADDTOGIS                   70207 non-null object
# ADDEDBY                    70213 non-null object
# WHATMODIFIED               11416 non-null object
# LASTLOGGED                 70213 non-null object
# LOGGEDBY                   70213 non-null object
# STREETLIGHTID              70212 non-null object
# SHIELD                     44 non-null object
# LASTPAINTED                8918 non-null object
# LEDINOPERATION             5457 non-null object
# XCOORDINAT                 70213 non-null float64
# YCOORDINAT                 70213 non-null float64
# ISMETERED_DESC             70207 non-null object
# LIGHTTYPE_DESC             70062 non-null object
# POLETYPE_DESC              34419 non-null object
# POLEHEIGHT_DESC            69766 non-null object
# POWERFEED_DESC             70191 non-null object
# NUMBERARMS_DESC            66309 non-null object
# PROXIMITY_DESC             70061 non-null object
# QUADRANT_DESC              70213 non-null object
# ROADTYPE_DESC              70213 non-null object
# OWNER_DESC                 70213 non-null object
# WARD_DESC                  70213 non-null object
# RMS_DESC                   70191 non-null object
# CONDITION_DESC             3945 non-null object
# SHIELD_DESC                39 non-null object
# GLOBALID                   70213 non-null object
# LAST_EDITED_USER           0 non-null object
# LAST_EDITED_DATE           0 non-null object
# POLECOLOR                  18848 non-null object
# AFFILIATION                4175 non-null object
# SCRATCH                    70206 non-null object
# CCT                        5459 non-null object
# WATTAGE1                   70140 non-null object
# WATTAGE1_DESC              69986 non-null object
# POLECOMPOSITION            69852 non-null object
# POLECOMPOSITION_DESC       69852 non-null object
# ARMLENGTH1                 66304 non-null float64
# ARMLENGTH1_DESC            66302 non-null object
# NUMBERLIGHTS               70212 non-null float64
# NUMBERLIGHTS_DESC          70207 non-null object
# FIXTURESTYLE               70213 non-null int64
# FIXTURESTYLE_DESC          70213 non-null object
# TRAFFICCOMBO               69854 non-null object
# TRAFFICCOMBO_DESC          347 non-null object
# OTHEREQUIPMENT_DESC        342 non-null object
# LIGHTMANUFACTURER          63736 non-null object
# LIGHTMANUFACTURER_DESC     63736 non-null object
# TBASETYPE                  69718 non-null object
# TBASETYPE_DESC             69718 non-null object
# POLECOLOR_DESC             17914 non-null object
# CCT_DESC                   5459 non-null object
# INSPECTIONGROUP            9235 non-null object
# ASSETSTATUS                70213 non-null object
# ASSETSTATUS_DESC           70213 non-null object
# WHYINACTIVE                0 non-null object
# WATTAGE2                   2841 non-null object
# WATTAGE2_DESC              2831 non-null object
# FEEDMANHOLE                70 non-null object
# FEEDMANHOLE_DESC           70 non-null object
# ARMSTYLE                   60023 non-null object
# ARMSTYLE_DESC              60023 non-null object
# ARMLENGTH2                 747 non-null float64
# ARMLENGTH2_DESC            747 non-null object
# ROADCLASSIFICATION         70213 non-null int64
# ROADCLASSIFICATION_DESC    70213 non-null object
# ISMODIFIED                 610 non-null object
# ISMODIFIED_DESC            602 non-null object
# geometry                   70213 non-null object
# dtypes: float64(12), int64(9), object(75)
# memory usage: 51.4+ MB
#    OBJECTID FACILITYID PEPCOLIGHTID  ASSETTYPE  ISMETERED  LIGHTTYPE  \
# 0   1410957      6L993         None          1        0.0        6.0
# 1   1410958    74470DC  811386-7794          2        0.0        1.0
# 2   1410959    73076DC  000000-0000          1        0.0        1.0
# 3   1410960    72749DC  823387-5166          1        0.0        1.0
# 4   1410961      25877         None          2        0.0        1.0
#
#     POLETYPE POLEHEIGHT  POWERFEED  NUMBERARMS  PROXIMITY  STREETNAME  \
# 0         PP         28        1.0         1.0        4.0     11TH ST
# 1  Wood Pole         35        2.0         1.0        2.0  BENNING RD
# 2  Wood Pole         35        2.0         1.0        4.0     CLAY ST
# 3  Wood Pole         35        2.0         1.0        1.0     56TH ST
# 4         5A         28        1.0         1.0       10.0        O ST
#
#    QUADRANT                 CROSSSTREET  ROADTYPE  OWNER  WARD  \
# 0         3                        M ST         1      1     6
# 1         2                     34TH ST         4     11     7
# 2         2                     55TH ST         1     11     7
# 3         2  NANNIE HELEN BURROUGHS AVE         1     11     7
# 4         1                      9TH ST         4      1     2
#
#                COMMENTS HOUSENO  RMS  STREETSEGMID OTHEREQUIPMENT  CONDITION  \
# 0                  None    1100  0.0          5422           None        4.0
# 1                  None    3375  0.0          8947           None        NaN
# 2                  None    5400  0.0          5986           None        NaN
# 3  Update location only     616  0.0          3482           None        NaN
# 4                  None     910  0.0          1678           None        NaN
#
#   CREATED_USER CREATED_DATE                     ...                       \
# 0         None         None                     ...
# 1         None         None                     ...
# 2         None         None                     ...
# 3         None         None                     ...
# 4         None         None                     ...
#
#   TRAFFICCOMBO_DESC OTHEREQUIPMENT_DESC LIGHTMANUFACTURER  \
# 0              None                None    King Luminaire
# 1              None                None  General Electric
# 2              None                None  General Electric
# 3              None                None  General Electric
# 4              None                None  General Electric
#
#   LIGHTMANUFACTURER_DESC      TBASETYPE TBASETYPE_DESC POLECOLOR_DESC  \
# 0         King Luminaire  Non-Breakaway  Non-Breakaway          Black
# 1       General Electric             DB             DB           None
# 2       General Electric             DB             DB           None
# 3       General Electric             DB             DB           None
# 4       General Electric             DB             DB           None
#
#   CCT_DESC INSPECTIONGROUP ASSETSTATUS ASSETSTATUS_DESC WHYINACTIVE  WATTAGE2  \
# 0     4000            None      Active           Active        None      None
# 1     None            None      Active           Active        None      None
# 2     None            None      Active           Active        None      None
# 3     None            None      Active           Active        None      None
# 4     None            None      Active           Active        None      None
#
#    WATTAGE2_DESC FEEDMANHOLE FEEDMANHOLE_DESC         ARMSTYLE  \
# 0           None        None             None  Simple Teardrop
# 1           None        None             None    Regular Alley
# 2           None        None             None             None
# 3           None        None             None             None
# 4           None        None             None    Regular Alley
#
#      ARMSTYLE_DESC ARMLENGTH2 ARMLENGTH2_DESC ROADCLASSIFICATION  \
# 0  Simple Teardrop        NaN            None                 16
# 1    Regular Alley        NaN            None                 19
# 2             None        NaN            None                 19
# 3             None        NaN            None                 19
# 4    Regular Alley        NaN            None                 19
#
#   ROADCLASSIFICATION_DESC ISMODIFIED ISMODIFIED_DESC  \
# 0          Minor Arterial       None            None
# 1                   Local       None            None
# 2                   Local       None            None
# 3                   Local       None            None
# 4                   Local       None            None
#
#                                       geometry
# 0       POINT Z (-76.9916583058 38.87689854 0)
# 1     POINT Z (-76.9583962614 38.8959857572 0)
# 2  POINT Z (-76.92270552399999 38.892850182 0)
# 3      POINT Z (-76.920579846 38.8979190925 0)
# 4     POINT Z (-77.0245434031 38.9083958742 0)
#
# [5 rows x 96 columns]

# %%
repairs.join(streetlights_df, how='left', left_on)

# %%
plot_with_roads(repairs, markersize=2, alpha=0.5).compute()
# Out:
# [########################################] | 100% Completed | 27.9s
